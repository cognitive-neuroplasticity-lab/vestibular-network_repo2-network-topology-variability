# %%
# !pip -q install pandas

# %%
import pandas as pd

# %%
summary_df = pd.DataFrame({
    "Category": [
        "Repository",
        "Dataset Base",
        "Subjects Analysed",
        "Imaging Type",
        "Core Focus",
        "Status"
    ],
    "Value": [
        "vestibular-network_repo2",
        "Accessible normative rs-fMRI sample",
        "5",
        "Resting-state fMRI",
        "Network topology variability",
        "Complete"
    ]
})

summary_df
# Out:
#             Category                                Value
# 0         Repository             vestibular-network_repo2
# 1       Dataset Base  Accessible normative rs-fMRI sample
# 2  Subjects Analysed                                    5
# 3       Imaging Type                   Resting-state fMRI
# 4         Core Focus         Network topology variability
# 5             Status                             Complete

# %%
findings = [
    "Functional connectivity graphs were successfully constructed.",
    "Topology metrics varied across subjects.",
    "Higher density aligned with higher clustering.",
    "Most graphs were fully connected, while some showed fragmentation.",
    "The workflow is scalable to richer vestibular-focused analyses."
]

for f in findings:
    print("-", f)
# Out:
# - Functional connectivity graphs were successfully constructed.
# - Topology metrics varied across subjects.
# - Higher density aligned with higher clustering.
# - Most graphs were fully connected, while some showed fragmentation.
# - The workflow is scalable to richer vestibular-focused analyses.

# %%
limitations = [
    "Used a practical accessible sample rather than direct full ID1000 ingestion.",
    "Pilot sample size of five subjects.",
    "Whole-brain atlas approximation rather than vestibular-specific ROI graph only.",
    "No behavioral variables linked yet."
]

for l in limitations:
    print("-", l)
# Out:
# - Used a practical accessible sample rather than direct full ID1000 ingestion.
# - Pilot sample size of five subjects.
# - Whole-brain atlas approximation rather than vestibular-specific ROI graph only.
# - No behavioral variables linked yet.

# %%
next_df = pd.DataFrame({
    "Next Step": [
        "Expand sample size",
        "Use vestibular candidate ROIs only",
        "Link to spatial cognition tasks",
        "Build predictive models",
        "Run robustness analyses"
    ],
    "Future Repository": [
        "vestibular-network_repo2",
        "vestibular-network_repo3",
        "vestibular-network_repo3",
        "vestibular-network_repo4",
        "vestibular-network_repo5"
    ]
})

next_df
# Out:
#                             Next Step         Future Repository
# 0                  Expand sample size  vestibular-network_repo2
# 1  Use vestibular candidate ROIs only  vestibular-network_repo3
# 2     Link to spatial cognition tasks  vestibular-network_repo3
# 3             Build predictive models  vestibular-network_repo4
# 4             Run robustness analyses  vestibular-network_repo5

# %%
print("Notebook 5 complete.")
print("Repo establishes evidence for inter-individual vestibular-network topology variability.")
# Out:
# Notebook 5 complete.
# Repo establishes evidence for inter-individual vestibular-network topology variability.
